# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
# Загрузка данных
file_path = "data/monthly-sales-of-company-x-jan-6.csv"
df = pd.read_csv(file_path)
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)

# %%
# Проверка на стационарность (ADF-тест)
adf_result = adfuller(df['Count'])
is_stationary = adf_result[1] < 0.05

# %%
# Дифференцирование
if not is_stationary:
    diff_series = df['Count'].diff().dropna()
else:
    diff_series = df['Count']

# %%
# Построение модели ARIMA
model = ARIMA(df['Count'], order=(1, 1, 1))
model_fit = model.fit()

# %%
# Прогноз модели
forecast = model_fit.predict(start=1, end=len(df)-1, typ="levels")

# %%
# Оценка качества модели
mse = mean_squared_error(df['Count'].iloc[1:], forecast)

# %%
# Визуализация
plt.figure(figsize=(12, 5))
plt.plot(df.index, df['Count'], label='Оригинальный ряд')
plt.plot(df.index[1:], forecast, label='ARIMA(1,1,1) прогноз', linestyle='--')
plt.title('ARIMA модель для временного ряда продаж')
plt.xlabel('Дата')
plt.ylabel('Продажи')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df.head(), is_stationary, mse, model_fit.summary()
# Out:
# (            Count
#  Month
#  1965-01-01    154
#  1965-02-01     96
#  1965-03-01     73
#  1965-04-01     49
#  1965-05-01     36,
#  np.False_,
#  8783.689649093212,
#  <class 'statsmodels.iolib.summary.Summary'>
#  """
#                                 SARIMAX Results
# ...
#  Dep. Variable:                  Count   No. Observations:                   77
#  Model:                 ARIMA(1, 1, 1)   Log Likelihood                -452.941
#  Date:                Thu, 22 May 2025   AIC                            911.883
#  Time:                        16:36:32   BIC                            918.875
#  Sample:                    01-01-1965   HQIC                           914.677
#                           - 05-01-1971
#  Covariance Type:                  opg
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
#  ------------------------------------------------------------------------------
# ...
