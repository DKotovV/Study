# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings("ignore")

# %%
# Загрузка данных
births_df = pd.read_csv('data/daily-total-female-births-in-cal.csv')
births_df['Date'] = pd.to_datetime(births_df['Date'])
births_df.set_index('Date', inplace=True)

sales_df = pd.read_csv('data/monthly-sales-of-company-x-jan-6.csv')
sales_df['Month'] = pd.to_datetime(sales_df['Month'])
sales_df.set_index('Month', inplace=True)

# %%
# ADF-тест
def check_stationarity(series, name="Ряд"):
    result = adfuller(series)
    print(f"{name}: p-value = {result[1]:.5f}")
    return result[1] < 0.05

print("ADF Test Results:")
births_stationary = check_stationarity(births_df['Count'], "Ряд рождаемости")
sales_stationary = check_stationarity(sales_df['Count'], "Ряд продаж")
# Out:
# ADF Test Results:
# Ряд рождаемости: p-value = 0.00005
# Ряд продаж: p-value = 0.98889

# %%
# Визуализация
fig, ax = plt.subplots(2, 1, figsize=(12, 6), sharex=False)
births_df['Count'].plot(ax=ax[0], title='Стационарный ряд: рождаемость')
sales_df['Count'].plot(ax=ax[1], title='Нестационарный ряд: продажи')
plt.tight_layout()
plt.show()

# %%
# MA модель
def fit_ma_model(series, q=1, title="MA модель"):
    model = ARIMA(series, order=(0, 0, q)).fit()
    forecast = model.predict()
    plt.figure(figsize=(12, 4))
    plt.plot(series, label='Оригинал')
    plt.plot(forecast, label=f'MA({q}) Предсказание', linestyle='--')
    plt.title(title)
    plt.legend()
    plt.show()
    mse = mean_squared_error(series[q:], forecast[q:])
    print(f"MSE для MA({q}) модели: {mse:.2f}")
    return model

# %%
# Модель DEMA / TEMA
def fit_exponential_smoothing(series, seasonal_periods=12, trend='add', seasonal=None, title="Exponential Smoothing"):
    model = ExponentialSmoothing(series,
                                  trend=trend,
                                  seasonal=seasonal,
                                  seasonal_periods=seasonal_periods).fit()
    forecast = model.fittedvalues
    plt.figure(figsize=(12, 4))
    plt.plot(series, label='Оригинал')
    plt.plot(forecast, label='Exponential Smoothing', linestyle='--')
    plt.title(title)
    plt.legend()
    plt.show()
    mse = mean_squared_error(series, forecast)
    print(f"MSE для экспоненциального сглаживания: {mse:.2f}")
    return model

# %%
# Применение моделей
print("\nСтационарный ряд (рождаемость):")
ma_births_model = fit_ma_model(births_df['Count'], q=3, title="MA(3) модель для рождаемости")

print("\nНестационарный ряд (продажи):")
smoothing_sales_model = fit_exponential_smoothing(
    sales_df['Count'],
    seasonal_periods=12,
    trend='add',
    seasonal=None,
    title="Exponential Smoothing (DEMA/TEMA альтернатива) для продаж"
)
# Out:
# Стационарный ряд (рождаемость):
# MSE для MA(3) модели: 50.56
#
# Нестационарный ряд (продажи):
# MSE для экспоненциального сглаживания: 9861.48

# %%
print("\n Выводы:")
print("""
1. Ряд рождаемости — стационарен (p-value < 0.05), успешно аппроксимирован моделью MA(3), с невысокой ошибкой.
2. Ряд продаж — нестационарен (p-value > 0.05), MA модель здесь не подходит.
3. Для ряда продаж применена модель экспоненциального сглаживания (альтернатива DEMA/TEMA), подходящая для трендовых и сезонных данных.
4. MA модели эффективны для стационарных рядов, в то время как экспоненциальное сглаживание — для нестационарных с трендом.
""")
# Out:
#  Выводы:
#
# 1. Ряд рождаемости — стационарен (p-value < 0.05), успешно аппроксимирован моделью MA(3), с невысокой ошибкой.
# 2. Ряд продаж — нестационарен (p-value > 0.05), MA модель здесь не подходит.
# 3. Для ряда продаж применена модель экспоненциального сглаживания (альтернатива DEMA/TEMA), подходящая для трендовых и сезонных данных.
# 4. MA модели эффективны для стационарных рядов, в то время как экспоненциальное сглаживание — для нестационарных с трендом.
